# %% [markdown]
# <a href="https://colab.research.google.com/github/SwimLane2/Python-Bootcamp/blob/main/Day%201.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello World \nThis is my first Python code.")
# Out:
# Hello World
# This is my first Python code.
